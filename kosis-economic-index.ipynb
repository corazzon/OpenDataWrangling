# %% [markdown]
# https://kosis.kr/statHtml/statHtml.do?orgId=101&tblId=DT_1C8015&conn_path=I2

# %%
import pandas as pd

# %%
df = pd.read_csv("data/kosis-economic-index.csv", encoding="cp949")
df
# Out:
#              시점   선행종합지수(2020=100)  재고순환지표(%p)  경제심리지수  \
# 0       1970.01                3.7           -       -
# 1       1970.02                3.7           -       -
# 2       1970.03                3.8           -       -
# 3       1970.04                3.8           -       -
# 4       1970.05                3.8           -       -
# ..          ...                ...         ...     ...
# 639     2023.04              109.4       -16.8    92.3
# 640     2023.05              109.8       -17.2    93.2
# 641  2023.06 p)              110.5       -13.0    94.6
# 642  2023.07 p)              111.1        -9.7    94.7
# 643  2023.08 p)              111.4        -8.0    94.6
#
#      기계류내수출하지수(선박제외)(2020=100)  건설수주액(실질)(십억원) 수출입물가비율(2015=100)  \
# 0                            -               -                 -
# 1                            -               -                 -
# 2                            -               -                 -
# 3                            -               -                 -
# 4                            -               -                 -
# ..                         ...             ...               ...
# 639                      101.3         10440.7              84.5
# 640                       99.9         10466.3              85.3
# 641                       99.0         11826.5              86.0
# 642                       99.4         12164.4              86.6
# 643                       99.1          9575.8              86.7
#
#     코스피(1980.1.4=100)  장단기금리차(%p)   동행종합지수(2020=100)  ...  소매판매액지수(2020=100)  \
# 0                   -           -                3.6  ...                  -
# 1                   -           -                3.7  ...                  -
# 2                   -           -                3.8  ...                  -
# 3                   -           -                3.8  ...                  -
# 4                   -           -                3.9  ...                  -
# ..                ...         ...                ...  ...                ...
# 639            2463.7       -0.05              110.0  ...              106.6
# 640            2488.4       -0.15              110.3  ...              105.9
# 641            2548.9       -0.16              110.3  ...              105.5
# 642            2572.6       -0.04              110.0  ...              104.9
# 643            2585.1        0.12              110.1  ...              104.0
#
#      내수출하지수(2020=100)  수입액(실질)(백만불)  비농림어업취업자수(천명)  후행종합지수(2020=100)  \
# 0                   -             -              -               3.6
# 1                   -             -              -               3.6
# 2                   -             -              -               3.8
# 3                   -             -              -               3.8
# 4                   -             -              -               3.8
# ..                ...           ...            ...               ...
# 639              96.4       47099.3        26928.9             113.4
# 640              96.7       47767.2        26948.0             113.7
# 641              96.8       47567.9        26946.1             113.9
# 642              97.0       46111.8        26930.2             113.8
# 643              96.7       45625.2        26915.3             113.9
#
#      생산자제품재고지수(2020=100)  소비자물가지수변화율(서비스)   소비재수입액(실질)(백만불)  취업자수(천명)  \
# 0                      -                -                 -         -
# 1                      -                -                 -         -
# 2                      -                -                 -         -
# 3                      -                -                 -         -
# 4                      -                -                 -         -
# ..                   ...              ...               ...       ...
# 639                120.1              3.9            9575.2   28420.3
# 640                122.2              3.8            9376.7   28466.5
# 641                122.2              3.6            9554.3   28465.4
# 642                120.6              3.3            9348.5   28447.9
# 643                120.3              3.1            9242.2   28425.6
#
#      CP유통수익률(%p)
# 0              -
# 1              -
# 2              -
# 3              -
# 4              -
# ..           ...
# 639          4.1
# 640          4.0
# 641          4.0
# 642          4.0
# 643          4.0
#
# [644 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 644 entries, 0 to 643
# Data columns (total 23 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   시점                           644 non-null    object
#  1    선행종합지수(2020=100)            644 non-null    float64
#  2    재고순환지표(%p)                  644 non-null    object
#  3    경제심리지수                      644 non-null    object
#  4    기계류내수출하지수(선박제외)(2020=100)   644 non-null    object
#  5    건설수주액(실질)(십억원)              644 non-null    object
#  6   수출입물가비율(2015=100)            644 non-null    object
#  7   코스피(1980.1.4=100)            644 non-null    object
#  8    장단기금리차(%p)                  644 non-null    object
#  9    동행종합지수(2020=100)            644 non-null    float64
#  10   광공업생산지수(2020=100)           644 non-null    object
#  11   서비스업생산지수(도소매업제외)(2020=100)  644 non-null    object
#  12   건설기성액(실질)(십억원)              644 non-null    object
#  13   소매판매액지수(2020=100)           644 non-null    object
#  14   내수출하지수(2020=100)            644 non-null    object
#  15   수입액(실질)(백만불)                644 non-null    object
#  16   비농림어업취업자수(천명)               644 non-null    object
#  17   후행종합지수(2020=100)            644 non-null    float64
#  18   생산자제품재고지수(2020=100)         644 non-null    object
#  19   소비자물가지수변화율(서비스)             644 non-null    object
#  20   소비재수입액(실질)(백만불)             644 non-null    object
#  21   취업자수(천명)                    644 non-null    object
#  22   CP유통수익률(%p)                 644 non-null    object
# dtypes: float64(3), object(20)
# memory usage: 115.8+ KB

# %%
df.describe()
# Out:
#         선행종합지수(2020=100)   동행종합지수(2020=100)   후행종합지수(2020=100)
# count         644.000000         644.000000         644.000000
# mean           43.921429          45.904658          45.723913
# std            32.301838          33.440069          32.853593
# min             3.700000           3.600000           3.600000
# 25%            13.475000          13.875000          13.675000
# 50%            37.700000          38.850000          44.600000
# 75%            70.700000          75.200000          71.850000
# max           111.400000         110.300000         113.900000
