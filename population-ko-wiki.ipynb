# %%
import pandas as pd

# %%
url = "https://ko.wikipedia.org/wiki/%EB%8C%80%ED%95%9C%EB%AF%BC%EA%B5%AD%EC%9D%98_%EC%9D%B8%EA%B5%AC"
url
# Out:
# 'https://ko.wikipedia.org/wiki/%EB%8C%80%ED%95%9C%EB%AF%BC%EA%B5%AD%EC%9D%98_%EC%9D%B8%EA%B5%AC'

# %%
table = pd.read_html(url, thousands=',')
len(table)
# Out:
# 3

# %%
table[0]
# Out:
#            구간  연평균 출생아수  연평균 사망자수  연평균 자연증가  조출생률  조사망률  자연증가율  합계출산율  영아사망률
# 0   1950–1955    722000    331000    391000  35.8  16.4   19.4   5.05  138.0
# 1   1955–1960   1049000    356000    693000  45.4  15.4   30.0   6.33  114.4
# 2   1960–1965   1067000    347000    720000  39.9  13.0   27.0   5.63   89.7
# 3   1965–1970    985000    298000    687000  32.9   9.9   23.0   4.71   64.2
# 4   1970–1975   1004000    259000    746000  30.4   7.8   22.5   4.28   38.1
# 5   1975–1980    833000    253000    581000  23.1   7.0   16.1   2.92   33.2
# 6   1980–1985    795000    248000    547000  20.4   6.4   14.0   2.23   24.6
# 7   1985–1990    647000    239000    407000  15.5   5.7    9.8   1.60   14.9
# 8   1990–1995    702000    239000    463000  16.0   5.5   10.6   1.70    9.7
# 9   1995–2000    615000    247000    368000  13.6   5.5    8.1   1.51    6.6
# 10  2000–2005    476000    245000    231000  10.2   5.3    5.0   1.22    5.3
# 11  2005–2010    477000    243000    234000  10.0   5.1    4.9   1.29    3.8
# 12  2010–2015    455000    275000    180000   NaN   NaN    NaN   1.26    NaN

# %%
df = table[1]
df.shape
# Out:
# (95, 9)

# %%
df.head()
# Out:
#    연도 (년)     추계인구(명)  출생자수(명)  사망자수(명)  자연증가수(명)  조출생률(%)  조사망률(%)  자연증가율(%)  \
# 0    1925  12997611.0   558897   359042    199855     43.0     27.6      15.4
# 1    1926  13052741.0   511667   337948    173719     39.2     25.9      13.3
# 2    1927  13037169.0   534524   353818    180706     41.0     27.1      13.9
# 3    1928  13105131.0   566142   357701    208441     43.2     27.3      15.9
# 4    1929  13124279.0   566969   414366    152603     43.2     31.6      11.6
#
#    합계출산율(%)
# 0      6.59
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
df.tail()
# Out:
#     연도 (년)     추계인구(명)  출생자수(명)  사망자수(명)  자연증가수(명)  조출생률(%)  조사망률(%)  \
# 90    2015  51014947.0   438420   275895    162925      8.6      5.4
# 91    2016  51245707.0   406243   280827    125416      7.9      5.5
# 92    2017  51446201.0   357771   285534     72237      7.0      5.5
# 93    2018  51635256.0   326822   298820     28002      6.4      5.8
# 94    2019         NaN   303054   295132      7922      5.9      5.7
#
#     자연증가율(%)  합계출산율(%)
# 90       3.2      1.24
# 91       2.4      1.17
# 92       1.5      1.05
# 93       0.6      0.98
# 94       0.2      0.92

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# sns.set(font="Malgun Gothic")
sns.set(font="AppleGothic")

# %%
from IPython.display import set_matplotlib_formats
set_matplotlib_formats("retina")

# %%
plt.figure(figsize=(15, 4))
plt.xticks(rotation=60)
sns.pointplot(data=df, x="연도 (년)", y="추계인구(명)")

# %%
plt.figure(figsize=(15, 4))
plt.xticks(rotation=60)
sns.lineplot(data=df, x="연도 (년)", y="추계인구(명)")

# %%
plt.figure(figsize=(15, 4))
plt.xticks(rotation=60)
sns.pointplot(data=df, x="연도 (년)", y="출생자수(명)")

# %%
(10**6) * 0.3
# Out:
# 300000.0

# %%
plt.figure(figsize=(15, 4))
sns.lineplot(data=df, x="연도 (년)", y="출생자수(명)")

# %%
plt.figure(figsize=(15, 4))
plt.xticks(rotation=60)
sns.pointplot(data=df, x="연도 (년)", y="사망자수(명)")

# %%
plt.figure(figsize=(15, 4))
plt.xticks(rotation=60)
sns.lineplot(data=df, x="연도 (년)", y="사망자수(명)")

# %%
plt.figure(figsize=(15, 8))
plt.xticks(rotation=60)
sns.pointplot(data=df, x="연도 (년)", y="출생자수(명)")
sns.pointplot(data=df, x="연도 (년)", y="사망자수(명)", color="orange")

# %%
df_pop = df[['연도 (년)', '출생자수(명)', '사망자수(명)']]
df_pop = df_pop.set_index("연도 (년)")
df_pop.head()
# Out:
#         출생자수(명)  사망자수(명)
# 연도 (년)
# 1925     558897   359042
# 1926     511667   337948
# 1927     534524   353818
# 1928     566142   357701
# 1929     566969   414366

# %%
df_pop.plot(figsize=(15, 4))

# %%
df_pop[-50:].plot(figsize=(15, 8))

# %%
plt.figure(figsize=(15, 8))
plt.xticks(rotation=60)
sns.pointplot(data=df[-50:], x="연도 (년)", y="출생자수(명)")
sns.pointplot(data=df[-50:], x="연도 (년)", y="사망자수(명)", color="orange")

# %%
plt.figure(figsize=(15, 4))
plt.xticks(rotation=60)
sns.barplot(data=df, x="연도 (년)", y="추계인구(명)", palette="Blues")

# %%
plt.figure(figsize=(15, 4))
plt.xticks(rotation=60)
sns.pointplot(data=df, x="연도 (년)", y="추계인구(명)", palette="Blues")

# %%
plt.figure(figsize=(15, 4))
plt.xticks(rotation=60)
sns.lineplot(data=df, x="연도 (년)", y="추계인구(명)")

# %%
table[1].style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_4140333e_b485_11ea_8692_acbc3281177frow0_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow0_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow0_col2 {
#             background-color:  #b5c4df;
#             color:  #000000;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow0_col3 {
#             background-color:  #a2bcda;
#             color:  #000000;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow0_col4 {
#             background-color:  #d2d2e7;
#             color:  #000000;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow0_col5 {
#             background-color:  #02395a;
#             color:  #f1f1f1;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow0_col6 {
#             background-color:  #045e94;
#             color:  #f1f1f1;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow0_col7 {
#             background-color:  #7bacd1;
#             color:  #000000;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow0_col8 {
#             background-color:  #034165;
#             color:  #f1f1f1;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow1_col0 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow1_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow1_col2 {
#             background-color:  #cacee5;
#             color:  #000000;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow1_col3 {
#             background-color:  #b5c4df;
#             color:  #000000;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow1_col4 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow1_col5 {
#             background-color:  #045585;
#             color:  #f1f1f1;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow1_col6 {
#             background-color:  #0569a5;
#             color:  #f1f1f1;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow1_col7 {
#             background-color:  #96b6d7;
#             color:  #000000;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow1_col8 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow2_col0 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow2_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow2_col2 {
#             background-color:  #c0c9e2;
#             color:  #000000;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow2_col3 {
#             background-color:  #a8bedc;
#             color:  #000000;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow2_col4 {
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow2_col5 {
#             background-color:  #034871;
#             color:  #f1f1f1;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow2_col6 {
#             background-color:  #046299;
#             color:  #f1f1f1;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow2_col7 {
#             background-color:  #8fb4d6;
#             color:  #000000;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow2_col8 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow3_col0 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow3_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow3_col2 {
#             background-color:  #b3c3de;
#             color:  #000000;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow3_col3 {
#             background-color:  #a4bcda;
#             color:  #000000;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow3_col4 {
#             background-color:  #ced0e6;
#             color:  #000000;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow3_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow3_col6 {
#             background-color:  #046097;
#             color:  #f1f1f1;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow3_col7 {
#             background-color:  #75a9cf;
#             color:  #000000;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow3_col8 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow4_col0 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow4_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow4_col2 {
#             background-color:  #b3c3de;
#             color:  #000000;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow4_col3 {
#             background-color:  #65a3cb;
#             color:  #000000;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow4_col4 {
#             background-color:  #dfddec;
#             color:  #000000;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow4_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow4_col6 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow4_col7 {
#             background-color:  #abbfdc;
#             color:  #000000;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow4_col8 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow5_col0 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow5_col1 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow5_col2 {
#             background-color:  #a9bfdc;
#             color:  #000000;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow5_col3 {
#             background-color:  #c2cbe2;
#             color:  #000000;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow5_col4 {
#             background-color:  #b7c5df;
#             color:  #000000;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow5_col5 {
#             background-color:  #023e62;
#             color:  #f1f1f1;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow5_col6 {
#             background-color:  #1e80b8;
#             color:  #000000;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow5_col7 {
#             background-color:  #4295c3;
#             color:  #000000;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow5_col8 {
#             background-color:  #034973;
#             color:  #f1f1f1;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow6_col0 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow6_col1 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow6_col2 {
#             background-color:  #a8bedc;
#             color:  #000000;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow6_col3 {
#             background-color:  #adc1dd;
#             color:  #000000;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow6_col4 {
#             background-color:  #c0c9e2;
#             color:  #000000;
#         }    #T_4140333e_b485_11ea_8692_acbc3281177frow6_col5 {
#             background-color:  #023d60;
#             color:  #f1f1f1;
