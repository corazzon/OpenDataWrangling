# %% [markdown]
# # 따릉이 자전거 대여소 위치

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
from plotnine import *
# 지도 표현을 위해
import folium

# %%
df = pd.read_csv('data/seoul_bike/bike_rent_station.csv')
df.shape
# Out:
# (1463, 5)

# %%
df.head()
# Out:
#                    대여소   상태                            주소         위도  \
# 0  광진교 남단 사거리(디지털프라자앞)  운영중  서울특별시 강동구 구천면로 171 376 남단사거리  37.541805
# 1            해공공원(천호동)  운영중        서울특별시 강동구 올림픽로 702 265  37.545219
# 2               해공도서관앞  운영중        서울특별시 강동구 올림픽로 702 367  37.543915
# 3       삼성광나루아파트 버스정류장  운영중    서울특별시 강동구 상암로3길 77 암사동 534  37.553349
# 4           롯데캐슬 115동앞  운영중   서울특별시 강동구 양재대로 1665 명일동 304  37.554920
#
#            경도
# 0  127.124718
# 1  127.125916
# 2  127.125458
# 3  127.128860
# 4  127.142799

# %%
df.head()
# Out:
#                    대여소   상태                            주소         위도  \
# 0  광진교 남단 사거리(디지털프라자앞)  운영중  서울특별시 강동구 구천면로 171 376 남단사거리  37.541805
# 1            해공공원(천호동)  운영중        서울특별시 강동구 올림픽로 702 265  37.545219
# 2               해공도서관앞  운영중        서울특별시 강동구 올림픽로 702 367  37.543915
# 3       삼성광나루아파트 버스정류장  운영중    서울특별시 강동구 상암로3길 77 암사동 534  37.553349
# 4           롯데캐슬 115동앞  운영중   서울특별시 강동구 양재대로 1665 명일동 304  37.554920
#
#            경도
# 0  127.124718
# 1  127.125916
# 2  127.125458
# 3  127.128860
# 4  127.142799

# %%
df.tail()
# Out:
#            대여소   상태                                         주소         위도  \
# 1458     중랑센터2  운영중  서울특별시 금천구 벚꽃로 309 가산동 371-9 우림라이온스밸리 B동 앞 -67.442963
# 1459  상암센터 정비실  운영중                    서울특별시 마포구 월드컵로 251 운영센터   0.000000
# 1460       위트콤  운영중                      서울특별시 서초구 방배로 110 위트콤   0.000000
# 1461     위트콤공장  운영중                  서울특별시 서초구 방배로 110 석교빌딩 4층   0.000000
# 1462      중랑센터  운영중         서울특별시 성동구 자동차시장 3길 64 (물재생센터) 운영센터   0.000000
#
#              경도
# 1458  103.60833
# 1459    0.00000
# 1460    0.00000
# 1461    0.00000
# 1462    0.00000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1463 entries, 0 to 1462
# Data columns (total 5 columns):
# 대여소    1463 non-null object
# 상태     1463 non-null object
# 주소     1463 non-null object
# 위도     1463 non-null float64
# 경도     1463 non-null float64
# dtypes: float64(2), object(3)
# memory usage: 57.2+ KB

# %%
df.isnull().sum()
# Out:
# 대여소    0
# 상태     0
# 주소     0
# 위도     0
# 경도     0
# dtype: int64

# %%
df.shape
# Out:
# (1463, 5)

# %%
geo_df = df.loc[(df['위도'] > 37) & (df['경도'] > 125)]
geo_df.shape
# Out:
# (1456, 5)

# %%
(ggplot(geo_df)
 + aes(x='경도', y='위도')
 + geom_point()
 + theme(text=element_text(family='NanumBarunGothic'))
)
# Out:
# <ggplot: (290882340)>
