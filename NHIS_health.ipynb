# %% [markdown]
# ## 라이브러리 로드

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## 한글폰트 설정

# %%
import matplotlib.pyplot as plt
from IPython.display import set_matplotlib_formats

# Window 의 한글 폰트 설정
# plt.rc('font',family='Malgun Gothic')
# Mac 의 한글 폰트 설정
plt.rc('font', family='AppleGothic') 
plt.rc('axes', unicode_minus=False)

# 레티나 설정을 해주면 글씨가 좀 더 선명하게 보입니다.
set_matplotlib_formats('retina')

# %% [markdown]
# ## 데이터 불러오기

# %%
df = pd.read_csv("data/NHIS/NHIS_OPEN_GJ_2017.CSV", encoding="cp949")
df.shape
# Out:
# (1000000, 34)

# %% [markdown]
# ### 데이터 미리보기

# %%
df.sample()
# Out:
#         기준년도  가입자일련번호  성별코드  연령대코드(5세단위)  시도코드  신장(5Cm단위)  체중(5Kg 단위)  허리둘레  \
# 693174  2017   693175     2           12    47      160.0        65.0  85.0
#
#         시력(좌)  시력(우)  ...  감마지티피  흡연상태  음주여부  구강검진 수검여부  치아우식증유무  결손치유무  \
# 693174    1.0    0.8  ...   20.0   1.0   0.0          0      NaN    NaN
#
#         치아마모증유무  제3대구치(사랑니)이상  치석   데이터공개일자
# 693174      NaN           NaN NaN  20181126
#
# [1 rows x 34 columns]

# %% [markdown]
# ## 기본정보 보기

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 34 columns):
# 기준년도            1000000 non-null int64
# 가입자일련번호         1000000 non-null int64
# 성별코드            1000000 non-null int64
# 연령대코드(5세단위)     1000000 non-null int64
# 시도코드            1000000 non-null int64
# 신장(5Cm단위)       999738 non-null float64
# 체중(5Kg 단위)      999732 non-null float64
# 허리둘레            999560 non-null float64
# 시력(좌)           999712 non-null float64
# 시력(우)           999721 non-null float64
# 청력(좌)           999758 non-null float64
# 청력(우)           999757 non-null float64
# 수축기혈압           999924 non-null float64
# 이완기혈압           999923 non-null float64
# 식전혈당(공복혈당)      999957 non-null float64
# 총콜레스테롤          999957 non-null float64
# 트리글리세라이드        999957 non-null float64
# HDL콜레스테롤        999956 non-null float64
# LDL콜레스테롤        997101 non-null float64
# 혈색소             999944 non-null float64
# 요단백             995141 non-null float64
# 혈청크레아티닌         999956 non-null float64
# (혈청지오티)AST      999958 non-null float64
# (혈청지오티)ALT      999956 non-null float64
# 감마지티피           999955 non-null float64
# 흡연상태            999840 non-null float64
# 음주여부            999475 non-null float64
# 구강검진 수검여부       1000000 non-null int64
# 치아우식증유무         0 non-null float64
# 결손치유무           0 non-null float64
# 치아마모증유무         0 non-null float64
# 제3대구치(사랑니)이상    0 non-null float64
# 치석              398748 non-null float64
# 데이터공개일자         1000000 non-null int64
# dtypes: float64(27), int64(7)
# memory usage: 259.4 MB

# %%
df.columns
# Out:
# Index(['기준년도', '가입자일련번호', '성별코드', '연령대코드(5세단위)', '시도코드', '신장(5Cm단위)',
#        '체중(5Kg 단위)', '허리둘레', '시력(좌)', '시력(우)', '청력(좌)', '청력(우)', '수축기혈압',
#        '이완기혈압', '식전혈당(공복혈당)', '총콜레스테롤', '트리글리세라이드', 'HDL콜레스테롤', 'LDL콜레스테롤',
#        '혈색소', '요단백', '혈청크레아티닌', '(혈청지오티)AST', '(혈청지오티)ALT', '감마지티피', '흡연상태',
#        '음주여부', '구강검진 수검여부', '치아우식증유무', '결손치유무', '치아마모증유무', '제3대구치(사랑니)이상',
#        '치석', '데이터공개일자'],
#       dtype='object')

# %%
df.dtypes
# Out:
# 기준년도              int64
# 가입자일련번호           int64
# 성별코드              int64
# 연령대코드(5세단위)       int64
# 시도코드              int64
# 신장(5Cm단위)       float64
# 체중(5Kg 단위)      float64
# 허리둘레            float64
# 시력(좌)           float64
# 시력(우)           float64
# 청력(좌)           float64
# 청력(우)           float64
# 수축기혈압           float64
# 이완기혈압           float64
# 식전혈당(공복혈당)      float64
# 총콜레스테롤          float64
# 트리글리세라이드        float64
# HDL콜레스테롤        float64
# LDL콜레스테롤        float64
# 혈색소             float64
# 요단백             float64
# 혈청크레아티닌         float64
# (혈청지오티)AST      float64
# (혈청지오티)ALT      float64
# 감마지티피           float64
# 흡연상태            float64
# 음주여부            float64
# 구강검진 수검여부         int64
# 치아우식증유무         float64
# 결손치유무           float64
# 치아마모증유무         float64
# 제3대구치(사랑니)이상    float64
# 치석              float64
# 데이터공개일자           int64
# dtype: object

# %% [markdown]
# ## 결측치 보기

# %%
df.isnull().sum()
# Out:
# 기준년도                  0
# 가입자일련번호               0
# 성별코드                  0
# 연령대코드(5세단위)           0
# 시도코드                  0
# 신장(5Cm단위)           262
# 체중(5Kg 단위)          268
# 허리둘레                440
# 시력(좌)               288
# 시력(우)               279
# 청력(좌)               242
# 청력(우)               243
# 수축기혈압                76
# 이완기혈압                77
# 식전혈당(공복혈당)           43
# 총콜레스테롤               43
# 트리글리세라이드             43
# HDL콜레스테롤             44
# LDL콜레스테롤           2899
# 혈색소                  56
# 요단백                4859
# 혈청크레아티닌              44
# (혈청지오티)AST           42
# (혈청지오티)ALT           44
# 감마지티피                45
# 흡연상태                160
# 음주여부                525
# 구강검진 수검여부             0
# 치아우식증유무         1000000
# 결손치유무           1000000
# 치아마모증유무         1000000
# 제3대구치(사랑니)이상    1000000
# 치석               601252
# 데이터공개일자               0
# dtype: int64

# %%
df.isna().sum()
# Out:
# 기준년도                  0
# 가입자일련번호               0
# 성별코드                  0
# 연령대코드(5세단위)           0
# 시도코드                  0
# 신장(5Cm단위)           262
# 체중(5Kg 단위)          268
# 허리둘레                440
# 시력(좌)               288
# 시력(우)               279
# 청력(좌)               242
# 청력(우)               243
# 수축기혈압                76
# 이완기혈압                77
# 식전혈당(공복혈당)           43
# 총콜레스테롤               43
# 트리글리세라이드             43
# HDL콜레스테롤             44
# LDL콜레스테롤           2899
# 혈색소                  56
# 요단백                4859
# 혈청크레아티닌              44
# (혈청지오티)AST           42
# (혈청지오티)ALT           44
# 감마지티피                45
# 흡연상태                160
# 음주여부                525
# 구강검진 수검여부             0
# 치아우식증유무         1000000
# 결손치유무           1000000
# 치아마모증유무         1000000
# 제3대구치(사랑니)이상    1000000
# 치석               601252
# 데이터공개일자               0
# dtype: int64

# %% [markdown]
# ## 성별코드

# %%
df["성별코드"].describe()
# Out:
# count    1000000.000000
# mean           1.468828
# std            0.499028
# min            1.000000
# 25%            1.000000
# 50%            1.000000
# 75%            2.000000
# max            2.000000
# Name: 성별코드, dtype: float64

# %%
df["성별코드"].value_counts()
# Out:
# 1    531172
# 2    468828
# Name: 성별코드, dtype: int64

# %% [markdown]
# ## 연령대코드

# %%
df["연령대코드(5세단위)"].describe()
# Out:
# count    1000000.000000
# mean          10.539593
# std            2.860117
# min            5.000000
# 25%            8.000000
# 50%           11.000000
# 75%           13.000000
# max           18.000000
# Name: 연령대코드(5세단위), dtype: float64

# %%
df["연령대코드(5세단위)"].value_counts()
# Out:
# 9     130931
# 11    129849
# 10    118368
# 12    112183
# 13    106507
# 8      84691
# 7      77665
# 6      64958
# 14     53627
# 15     51588
# 16     25986
# 5      23255
# 17     16228
# 18      4164
# Name: 연령대코드(5세단위), dtype: int64

# %% [markdown]
# ## 시력

# %%
df[["시력(좌)", "시력(우)"]].head()
# Out:
#    시력(좌)  시력(우)
# 0    1.0    1.2
# 1    1.2    1.0
# 2    1.0    0.8
# 3    0.9    1.0
# 4    1.5    1.5

# %%
df[["시력(좌)", "시력(우)"]].describe()
# Out:
#                시력(좌)          시력(우)
# count  999712.000000  999721.000000
# mean        0.978897       0.976267
# std         0.610948       0.605323
# min         0.100000       0.100000
# 25%         0.700000       0.700000
# 50%         1.000000       1.000000
# 75%         1.200000       1.200000
# max         9.900000       9.900000

# %%
sns.countplot(data=df, x="연령대코드(5세단위)", hue="성별코드")

# %%
sns.countplot(data=df, x="연령대코드(5세단위)", hue="흡연상태")

# %%
sns.countplot(data=df, x="연령대코드(5세단위)", hue="음주여부")

# %%
df.columns
# Out:
# Index(['기준년도', '가입자일련번호', '성별코드', '연령대코드(5세단위)', '시도코드', '신장(5Cm단위)',
#        '체중(5Kg 단위)', '허리둘레', '시력(좌)', '시력(우)', '청력(좌)', '청력(우)', '수축기혈압',
#        '이완기혈압', '식전혈당(공복혈당)', '총콜레스테롤', '트리글리세라이드', 'HDL콜레스테롤', 'LDL콜레스테롤',
#        '혈색소', '요단백', '혈청크레아티닌', '(혈청지오티)AST', '(혈청지오티)ALT', '감마지티피', '흡연상태',
#        '음주여부', '구강검진 수검여부', '치아우식증유무', '결손치유무', '치아마모증유무', '제3대구치(사랑니)이상',
#        '치석', '데이터공개일자'],
#       dtype='object')

# %%
df_sample = df.sample(10000)

# %%
sns.barplot(data=df_sample, x="연령대코드(5세단위)", 
            y="총콜레스테롤", hue="음주여부")

# %%
sns.barplot(data=df_sample, x="연령대코드(5세단위)", 
            y="총콜레스테롤", hue="흡연상태")

# %%
# 트리글리세라이드(중성지방)
sns.barplot(data=df_sample, x="연령대코드(5세단위)", 
            y="트리글리세라이드", hue="흡연상태")

# %%
sns.barplot(data=df_sample, x="연령대코드(5세단위)", 
            y="트리글리세라이드", hue="음주여부")

# %%
df_group = df.groupby(
    ["연령대코드(5세단위)", "흡연상태", "음주여부"])["가입자일련번호"].count().reset_index()
df_group.columns = ["연령대코드(5세단위)", "흡연상태", "음주여부", "인원수"]
df_group.head()
# Out:
#    연령대코드(5세단위)  흡연상태  음주여부   인원수
# 0            5   1.0   0.0  7034
# 1            5   1.0   1.0  9202
# 2            5   2.0   0.0   311
# 3            5   2.0   1.0   978
# 4            5   3.0   0.0  1254

# %%
sns.barplot(data=df_group, x="연령대코드(5세단위)", y="인원수", hue="음주여부")

# %%
sns.barplot(data=df_group, x="연령대코드(5세단위)", y="인원수", hue="흡연상태")

# %%
sns.swarmplot(data=df_group, x="연령대코드(5세단위)", y="인원수", hue="흡연상태")

# %%
sns.barplot(data=df_sample, x="음주여부", y="체중(5Kg 단위)", hue="성별코드")

# %%
sns.barplot(data=df_sample, 
            x="연령대코드(5세단위)", 
            y="체중(5Kg 단위)", hue="음주여부")

# %%
sns.barplot(data=df_sample, 
            x="연령대코드(5세단위)", 
            y="체중(5Kg 단위)", hue="흡연상태")

# %%
sns.barplot(data=df_sample, 
            x="연령대코드(5세단위)", 
            y="체중(5Kg 단위)")

# %%
sns.lmplot(
    data=df_sample[:1000], x="신장(5Cm단위)", 
    y="체중(5Kg 단위)", hue="연령대코드(5세단위)")

# %%
sns.distplot(df_sample.loc[df_sample["시력(좌)"].notnull(), "시력(좌)"])

# %%
sns.scatterplot(
    data=df_sample, x="시력(좌)", 
    y="시력(우)", hue="연령대코드(5세단위)")

# %%
df_sample[["시력(좌)", "시력(우)"]].head()
# Out:
#         시력(좌)  시력(우)
# 969888    0.7    0.9
# 692536    1.0    0.9
# 926384    1.2    1.2
# 570942    0.8    0.9
# 591691    1.2    1.0

# %%
df_sample[["시력(좌)", "시력(우)"]].describe()
# Out:
#              시력(좌)        시력(우)
# count  9998.000000  9998.000000
# mean      0.978306     0.976025
# std       0.616072     0.616055
# min       0.100000     0.100000
# 25%       0.700000     0.700000
# 50%       1.000000     1.000000
# 75%       1.200000     1.200000
# max       9.900000     9.900000

# %%
df[["시력(좌)", "시력(우)"]].plot.box()

# %%
sns.barplot(data=df, x="성별코드", y="시력(좌)")

# %%
df_eye = df_sample[(df_sample["시력(좌)"] < 3) & (df_sample["시력(우)"] < 3)]

# %%
sns.distplot(df_eye["시력(좌)"], bins=10)
sns.distplot(df_eye["시력(우)"], bins=10)

# %%
sns.lmplot(
    data=df_eye, x="시력(좌)", 
    y="시력(우)", hue="연령대코드(5세단위)", col="연령대코드(5세단위)", col_wrap=3)

# %%
df["흡연상태"].value_counts()
# Out:
# 1.0    608587
# 3.0    215061
# 2.0    176192
# Name: 흡연상태, dtype: int64

# %%
df["음주여부"].value_counts()
# Out:
# 0.0    502729
# 1.0    496746
# Name: 음주여부, dtype: int64

# %%
sns.scatterplot(data=df_sample, x="수축기혈압", y="이완기혈압", hue="연령대코드(5세단위)")

# %%
df_man = df_sample[df_sample["성별코드"] == 1].sample(1000)
df_small = df_man[['연령대코드(5세단위)', '체중(5Kg 단위)', '허리둘레', '시력(좌)', '시력(우)', '청력(좌)', '청력(우)', '수축기혈압',
       '이완기혈압', '식전혈당(공복혈당)', '총콜레스테롤', '트리글리세라이드', 'HDL콜레스테롤', 'LDL콜레스테롤',
       '혈색소', '요단백', '혈청크레아티닌', '(혈청지오티)AST', '(혈청지오티)ALT', '감마지티피', '흡연상태',
       '음주여부']]
df_corr = df_small.corr()
df_corr
# Out:
#              연령대코드(5세단위)  체중(5Kg 단위)      허리둘레     시력(좌)     시력(우)     청력(좌)  \
# 연령대코드(5세단위)     1.000000   -0.280529  0.084002 -0.134108 -0.110875  0.228528
# 체중(5Kg 단위)     -0.280529    1.000000  0.784248  0.058276  0.066543 -0.090194
# 허리둘레            0.084002    0.784248  1.000000 -0.012754  0.042720  0.004710
# 시력(좌)          -0.134108    0.058276 -0.012754  1.000000  0.396175 -0.096383
# 시력(우)          -0.110875    0.066543  0.042720  0.396175  1.000000  0.006245
# 청력(좌)           0.228528   -0.090194  0.004710 -0.096383  0.006245  1.000000
# 청력(우)           0.206932   -0.103713 -0.012160 -0.061884  0.019714  0.460171
# 수축기혈압           0.141306    0.248225  0.313440 -0.086713 -0.044793  0.016459
# 이완기혈압           0.018866    0.240314  0.254502 -0.050902 -0.053394 -0.058768
# 식전혈당(공복혈당)      0.173240    0.062085  0.175405 -0.101187  0.001714  0.090829
# 총콜레스테롤         -0.133353    0.113732  0.039345  0.026064  0.015630 -0.102542
# 트리글리세라이드       -0.050789    0.198134  0.204383 -0.009082 -0.011142 -0.035345
# HDL콜레스테롤       -0.067152   -0.208827 -0.280542  0.008850 -0.014783 -0.026333
# LDL콜레스테롤       -0.108200    0.092467  0.025445  0.033228  0.024865 -0.083259
# 혈색소            -0.356807    0.266574  0.136203  0.090966  0.120193 -0.121355
# 요단백             0.100340    0.022099  0.083583 -0.066310  0.057382  0.102292
# 혈청크레아티닌         0.113021   -0.010640  0.040419 -0.025395 -0.025090  0.044959
# (혈청지오티)AST      0.074415    0.096545  0.141975  0.006502 -0.011266 -0.022709
# (혈청지오티)ALT     -0.096283    0.355818  0.331547  0.029378  0.031320 -0.063941
# 감마지티피           0.042150    0.058934  0.124221 -0.029998 -0.021083 -0.038769
# 흡연상태           -0.109228    0.059519  0.048579  0.003473  0.063639 -0.027900
# 음주여부           -0.228243    0.127770  0.047258  0.016163  0.063163 -0.045833
#
#                 청력(우)     수축기혈압     이완기혈압  식전혈당(공복혈당)  ...  HDL콜레스테롤  \
# 연령대코드(5세단위)  0.206932  0.141306  0.018866    0.173240  ... -0.067152
# 체중(5Kg 단위)  -0.103713  0.248225  0.240314    0.062085  ... -0.208827
# 허리둘레        -0.012160  0.313440  0.254502    0.175405  ... -0.280542
# 시력(좌)       -0.061884 -0.086713 -0.050902   -0.101187  ...  0.008850
# 시력(우)        0.019714 -0.044793 -0.053394    0.001714  ... -0.014783
# 청력(좌)        0.460171  0.016459 -0.058768    0.090829  ... -0.026333
# 청력(우)        1.000000  0.004238 -0.047024    0.028858  ... -0.015905
# 수축기혈압        0.004238  1.000000  0.721099    0.147459  ... -0.019381
# 이완기혈압       -0.047024  0.721099  1.000000    0.093102  ... -0.026279
# 식전혈당(공복혈당)   0.028858  0.147459  0.093102    1.000000  ... -0.086756
# 총콜레스테롤      -0.088567  0.056332  0.139069    0.030312  ...  0.162687
# 트리글리세라이드    -0.025806  0.136554  0.169456    0.234894  ... -0.274950
# HDL콜레스테롤    -0.015905 -0.019381 -0.026279   -0.086756  ...  1.000000
# LDL콜레스테롤    -0.082879 -0.014191  0.052900   -0.055137  ... -0.018301
# 혈색소         -0.113677  0.061521  0.173835   -0.021301  ... -0.042309
# 요단백         -0.004552  0.086611  0.037661    0.268954  ... -0.061211
# 혈청크레아티닌      0.045379  0.027423 -0.010518    0.103937  ... -0.035942
# (혈청지오티)AST  -0.039498  0.144939  0.177279    0.063737  ... -0.048481
# (혈청지오티)ALT  -0.058063  0.147028  0.182221    0.120074  ... -0.150674
# 감마지티피       -0.012878  0.141071  0.176044    0.130200  ...  0.016072
# 흡연상태        -0.021788  0.044405  0.108570    0.088480  ... -0.031461
# 음주여부        -0.093181  0.081031  0.136245    0.006341  ...  0.143481
#
#              LDL콜레스테롤       혈색소       요단백   혈청크레아티닌  (혈청지오티)AST  (혈청지오티)ALT  \
# 연령대코드(5세단위) -0.108200 -0.356807  0.100340  0.113021    0.074415   -0.096283
# 체중(5Kg 단위)   0.092467  0.266574  0.022099 -0.010640    0.096545    0.355818
# 허리둘레         0.025445  0.136203  0.083583  0.040419    0.141975    0.331547
# 시력(좌)        0.033228  0.090966 -0.066310 -0.025395    0.006502    0.029378
# 시력(우)        0.024865  0.120193  0.057382 -0.025090   -0.011266    0.031320
# 청력(좌)       -0.083259 -0.121355  0.102292  0.044959   -0.022709   -0.063941
# 청력(우)       -0.082879 -0.113677 -0.004552  0.045379   -0.039498   -0.058063
# 수축기혈압       -0.014191  0.061521  0.086611  0.027423    0.144939    0.147028
# 이완기혈압        0.052900  0.173835  0.037661 -0.010518    0.177279    0.182221
# 식전혈당(공복혈당)  -0.055137 -0.021301  0.268954  0.103937    0.063737    0.120074
# 총콜레스테롤       0.856355  0.211586 -0.062613 -0.076867    0.063674    0.130419
# 트리글리세라이드    -0.019891  0.108797  0.028407 -0.019257    0.164626    0.213098
# HDL콜레스테롤    -0.018301 -0.042309 -0.061211 -0.035942   -0.048481   -0.150674
# LDL콜레스테롤     1.000000  0.189226 -0.069665 -0.069445   -0.020572    0.066766
# 혈색소          0.189226  1.000000 -0.081167 -0.165487    0.101515    0.232122
# 요단백         -0.069665 -0.081167  1.000000  0.322474    0.049162    0.027070
# 혈청크레아티닌     -0.069445 -0.165487  0.322474  1.000000   -0.002220   -0.039601
# (혈청지오티)AST  -0.020572  0.101515  0.049162 -0.002220    1.000000    0.700867
# (혈청지오티)ALT   0.066766  0.232122  0.027070 -0.039601    0.700867    1.000000
# 감마지티피       -0.042613  0.038929  0.041325  0.057259    0.464227    0.370194
# 흡연상태        -0.001742  0.127017  0.030168 -0.055798    0.062893    0.076587
# 음주여부         0.053960  0.151627 -0.016700 -0.051281    0.093721    0.042689
#
#                 감마지티피      흡연상태      음주여부
# 연령대코드(5세단위)  0.042150 -0.109228 -0.228243
# 체중(5Kg 단위)   0.058934  0.059519  0.127770
# 허리둘레         0.124221  0.048579  0.047258
# 시력(좌)       -0.029998  0.003473  0.016163
# 시력(우)       -0.021083  0.063639  0.063163
# 청력(좌)       -0.038769 -0.027900 -0.045833
# 청력(우)       -0.012878 -0.021788 -0.093181
# 수축기혈압        0.141071  0.044405  0.081031
# 이완기혈압        0.176044  0.108570  0.136245
# 식전혈당(공복혈당)   0.130200  0.088480  0.006341
# 총콜레스테롤       0.088520  0.058522  0.161713
# 트리글리세라이드     0.206640  0.135292  0.129412
# HDL콜레스테롤     0.016072 -0.031461  0.143481
# LDL콜레스테롤    -0.042613 -0.001742  0.053960
# 혈색소          0.038929  0.127017  0.151627
# 요단백          0.041325  0.030168 -0.016700
# 혈청크레아티닌      0.057259 -0.055798 -0.051281
# (혈청지오티)AST   0.464227  0.062893  0.093721
# (혈청지오티)ALT   0.370194  0.076587  0.042689
# 감마지티피        1.000000  0.180837  0.185889
# 흡연상태         0.180837  1.000000  0.237259
# 음주여부         0.185889  0.237259  1.000000
#
# [22 rows x 22 columns]

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df_corr, vmax=.8, square=False, annot=True)
