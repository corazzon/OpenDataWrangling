# %% [markdown]
# ## 라이브러리 로드

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## 한글폰트 설정

# %%
import matplotlib.pyplot as plt
from IPython.display import set_matplotlib_formats

# Window 의 한글 폰트 설정
# plt.rc('font',family='Malgun Gothic')
# Mac 의 한글 폰트 설정
plt.rc('font', family='AppleGothic') 
plt.rc('axes', unicode_minus=False)

# 레티나 설정을 해주면 글씨가 좀 더 선명하게 보입니다.
set_matplotlib_formats('retina')

# %% [markdown]
# ## 데이터 불러오기

# %%
df = pd.read_csv("data/NHIS/NHIS_OPEN_GJ_2017.CSV", encoding="cp949")
df.shape
# Out:
# (1000000, 34)

# %% [markdown]
# ### 데이터 미리보기

# %%
df.sample()
# Out:
#         기준년도  가입자일련번호  성별코드  연령대코드(5세단위)  시도코드  신장(5Cm단위)  체중(5Kg 단위)  허리둘레  \
# 937176  2017   937177     2           12    26      155.0        50.0  71.0
#
#         시력(좌)  시력(우)  ...  감마지티피  흡연상태  음주여부  구강검진 수검여부  치아우식증유무  결손치유무  \
# 937176    1.2    1.0  ...   12.0   1.0   0.0          0      NaN    NaN
#
#         치아마모증유무  제3대구치(사랑니)이상  치석   데이터공개일자
# 937176      NaN           NaN NaN  20181126
#
# [1 rows x 34 columns]

# %% [markdown]
# ## 기본정보 보기

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 34 columns):
# 기준년도            1000000 non-null int64
# 가입자일련번호         1000000 non-null int64
# 성별코드            1000000 non-null int64
# 연령대코드(5세단위)     1000000 non-null int64
# 시도코드            1000000 non-null int64
# 신장(5Cm단위)       999738 non-null float64
# 체중(5Kg 단위)      999732 non-null float64
# 허리둘레            999560 non-null float64
# 시력(좌)           999712 non-null float64
# 시력(우)           999721 non-null float64
# 청력(좌)           999758 non-null float64
# 청력(우)           999757 non-null float64
# 수축기혈압           999924 non-null float64
# 이완기혈압           999923 non-null float64
# 식전혈당(공복혈당)      999957 non-null float64
# 총콜레스테롤          999957 non-null float64
# 트리글리세라이드        999957 non-null float64
# HDL콜레스테롤        999956 non-null float64
# LDL콜레스테롤        997101 non-null float64
# 혈색소             999944 non-null float64
# 요단백             995141 non-null float64
# ...

# %%
df.columns
# Out:
# Index(['기준년도', '가입자일련번호', '성별코드', '연령대코드(5세단위)', '시도코드', '신장(5Cm단위)',
#        '체중(5Kg 단위)', '허리둘레', '시력(좌)', '시력(우)', '청력(좌)', '청력(우)', '수축기혈압',
#        '이완기혈압', '식전혈당(공복혈당)', '총콜레스테롤', '트리글리세라이드', 'HDL콜레스테롤', 'LDL콜레스테롤',
#        '혈색소', '요단백', '혈청크레아티닌', '(혈청지오티)AST', '(혈청지오티)ALT', '감마지티피', '흡연상태',
#        '음주여부', '구강검진 수검여부', '치아우식증유무', '결손치유무', '치아마모증유무', '제3대구치(사랑니)이상',
#        '치석', '데이터공개일자'],
#       dtype='object')

# %%
df.dtypes
# Out:
# 기준년도              int64
# 가입자일련번호           int64
# 성별코드              int64
# 연령대코드(5세단위)       int64
# 시도코드              int64
# 신장(5Cm단위)       float64
# 체중(5Kg 단위)      float64
# 허리둘레            float64
# 시력(좌)           float64
# 시력(우)           float64
# 청력(좌)           float64
# 청력(우)           float64
# 수축기혈압           float64
# 이완기혈압           float64
# 식전혈당(공복혈당)      float64
# 총콜레스테롤          float64
# 트리글리세라이드        float64
# HDL콜레스테롤        float64
# LDL콜레스테롤        float64
# 혈색소             float64
# 요단백             float64
# 혈청크레아티닌         float64
# (혈청지오티)AST      float64
# (혈청지오티)ALT      float64
# 감마지티피           float64
# 흡연상태            float64
# 음주여부            float64
# 구강검진 수검여부         int64
# 치아우식증유무         float64
# 결손치유무           float64
# 치아마모증유무         float64
# 제3대구치(사랑니)이상    float64
# 치석              float64
# 데이터공개일자           int64
# dtype: object

# %% [markdown]
# ## 결측치 보기

# %%
df.isnull().sum()
# Out:
# 기준년도                  0
# 가입자일련번호               0
# 성별코드                  0
# 연령대코드(5세단위)           0
# 시도코드                  0
# 신장(5Cm단위)           262
# 체중(5Kg 단위)          268
# 허리둘레                440
# 시력(좌)               288
# 시력(우)               279
# 청력(좌)               242
# 청력(우)               243
# 수축기혈압                76
# 이완기혈압                77
# 식전혈당(공복혈당)           43
# 총콜레스테롤               43
# 트리글리세라이드             43
# HDL콜레스테롤             44
# LDL콜레스테롤           2899
# 혈색소                  56
# 요단백                4859
# 혈청크레아티닌              44
# (혈청지오티)AST           42
# (혈청지오티)ALT           44
# 감마지티피                45
# 흡연상태                160
# 음주여부                525
# 구강검진 수검여부             0
# 치아우식증유무         1000000
# 결손치유무           1000000
# 치아마모증유무         1000000
# 제3대구치(사랑니)이상    1000000
# 치석               601252
# 데이터공개일자               0
# dtype: int64

# %%
df.isna().sum()
# Out:
# 기준년도                  0
# 가입자일련번호               0
# 성별코드                  0
# 연령대코드(5세단위)           0
# 시도코드                  0
# 신장(5Cm단위)           262
# 체중(5Kg 단위)          268
# 허리둘레                440
# 시력(좌)               288
# 시력(우)               279
# 청력(좌)               242
# 청력(우)               243
# 수축기혈압                76
# 이완기혈압                77
# 식전혈당(공복혈당)           43
# 총콜레스테롤               43
# 트리글리세라이드             43
# HDL콜레스테롤             44
# LDL콜레스테롤           2899
# 혈색소                  56
# 요단백                4859
# 혈청크레아티닌              44
# (혈청지오티)AST           42
# (혈청지오티)ALT           44
# 감마지티피                45
# 흡연상태                160
# 음주여부                525
# 구강검진 수검여부             0
# 치아우식증유무         1000000
# 결손치유무           1000000
# 치아마모증유무         1000000
# 제3대구치(사랑니)이상    1000000
# 치석               601252
# 데이터공개일자               0
# dtype: int64

# %% [markdown]
# ## 성별코드

# %%
df["성별코드"].describe()
# Out:
# count    1000000.000000
# mean           1.468828
# std            0.499028
# min            1.000000
# 25%            1.000000
# 50%            1.000000
# 75%            2.000000
# max            2.000000
# Name: 성별코드, dtype: float64

# %%
df["성별코드"].value_counts()
# Out:
# 1    531172
# 2    468828
# Name: 성별코드, dtype: int64

# %% [markdown]
# ## 연령대코드

# %%
df["연령대코드(5세단위)"].describe()
# Out:
# count    1000000.000000
# mean          10.539593
# std            2.860117
# min            5.000000
# 25%            8.000000
# 50%           11.000000
# 75%           13.000000
# max           18.000000
# Name: 연령대코드(5세단위), dtype: float64

# %%
df["연령대코드(5세단위)"].value_counts()
# Out:
# 9     130931
# 11    129849
# 10    118368
# 12    112183
# 13    106507
# 8      84691
# 7      77665
# 6      64958
# 14     53627
# 15     51588
# 16     25986
# 5      23255
# 17     16228
# 18      4164
# Name: 연령대코드(5세단위), dtype: int64

# %% [markdown]
# ## 시력

# %%
df[["시력(좌)", "시력(우)"]].head()
# Out:
#    시력(좌)  시력(우)
# 0    1.0    1.2
# 1    1.2    1.0
# 2    1.0    0.8
# 3    0.9    1.0
# 4    1.5    1.5

# %%
df[["시력(좌)", "시력(우)"]].describe()
# Out:
#                시력(좌)          시력(우)
# count  999712.000000  999721.000000
# mean        0.978897       0.976267
# std         0.610948       0.605323
# min         0.100000       0.100000
# 25%         0.700000       0.700000
# 50%         1.000000       1.000000
# 75%         1.200000       1.200000
# max         9.900000       9.900000

# %%
sns.countplot(data=df, x="연령대코드(5세단위)", hue="성별코드")

# %%
sns.countplot(data=df, x="연령대코드(5세단위)", hue="흡연상태")

# %%
sns.countplot(data=df, x="연령대코드(5세단위)", hue="음주여부")

# %%
df.columns
# Out:
# Index(['기준년도', '가입자일련번호', '성별코드', '연령대코드(5세단위)', '시도코드', '신장(5Cm단위)',
#        '체중(5Kg 단위)', '허리둘레', '시력(좌)', '시력(우)', '청력(좌)', '청력(우)', '수축기혈압',
#        '이완기혈압', '식전혈당(공복혈당)', '총콜레스테롤', '트리글리세라이드', 'HDL콜레스테롤', 'LDL콜레스테롤',
#        '혈색소', '요단백', '혈청크레아티닌', '(혈청지오티)AST', '(혈청지오티)ALT', '감마지티피', '흡연상태',
#        '음주여부', '구강검진 수검여부', '치아우식증유무', '결손치유무', '치아마모증유무', '제3대구치(사랑니)이상',
#        '치석', '데이터공개일자'],
#       dtype='object')

# %%
df_sample = df.sample(10000)

# %%
sns.barplot(data=df_sample, x="연령대코드(5세단위)", 
            y="총콜레스테롤", hue="음주여부")

# %%
sns.barplot(data=df_sample, x="연령대코드(5세단위)", 
            y="총콜레스테롤", hue="흡연상태")

# %%
# 트리글리세라이드(중성지방)
sns.barplot(data=df_sample, x="연령대코드(5세단위)", 
            y="트리글리세라이드", hue="흡연상태")

# %%
sns.barplot(data=df_sample, x="연령대코드(5세단위)", 
            y="트리글리세라이드", hue="음주여부")

# %%
df_group = df.groupby(
    ["연령대코드(5세단위)", "흡연상태", "음주여부"])["가입자일련번호"].count().reset_index()
df_group.columns = ["연령대코드(5세단위)", "흡연상태", "음주여부", "인원수"]
df_group.head()
# Out:
#    연령대코드(5세단위)  흡연상태  음주여부   인원수
# 0            5   1.0   0.0  7034
# 1            5   1.0   1.0  9202
# 2            5   2.0   0.0   311
# 3            5   2.0   1.0   978
# 4            5   3.0   0.0  1254

# %%
sns.barplot(data=df_group, x="연령대코드(5세단위)", y="인원수", hue="음주여부")

# %%
sns.barplot(data=df_group, x="연령대코드(5세단위)", y="인원수", hue="흡연상태")

# %%
sns.swarmplot(data=df_group, x="연령대코드(5세단위)", y="인원수", hue="흡연상태")

# %%
sns.barplot(data=df_sample, x="음주여부", y="체중(5Kg 단위)", hue="성별코드")

# %%
sns.barplot(data=df_sample, x="흡연상태", y="체중(5Kg 단위)", hue="성별코드")

# %%
sns.barplot(data=df_sample, 
            x="연령대코드(5세단위)", 
            y="체중(5Kg 단위)", hue="음주여부")

# %%
sns.barplot(data=df_sample, 
            x="연령대코드(5세단위)", 
            y="체중(5Kg 단위)", hue="흡연상태")

# %%
sns.barplot(data=df_sample, 
            x="연령대코드(5세단위)", 
            y="체중(5Kg 단위)")

# %%
sns.lmplot(
    data=df_sample[:1000], x="신장(5Cm단위)", 
    y="체중(5Kg 단위)", hue="연령대코드(5세단위)")

# %%
sns.distplot(df_sample.loc[df_sample["시력(좌)"].notnull(), "시력(좌)"])

# %%
sns.scatterplot(
    data=df_sample, x="시력(좌)", 
    y="시력(우)", hue="연령대코드(5세단위)")

# %%
df_sample[["시력(좌)", "시력(우)"]].head()
# Out:
#         시력(좌)  시력(우)
# 712530    1.0    0.5
# 851120    0.8    1.0
# 701575    0.8    1.0
# 587200    0.6    1.0
# 942065    1.5    1.2

# %%
df_sample[["시력(좌)", "시력(우)"]].describe()
# Out:
#              시력(좌)        시력(우)
# count  9997.000000  9997.000000
# mean      0.971511     0.968911
# std       0.583737     0.553773
# min       0.100000     0.100000
# 25%       0.700000     0.700000
# 50%       1.000000     1.000000
# 75%       1.200000     1.200000
# max       9.900000     9.900000

# %%
df[["시력(좌)", "시력(우)"]].plot.box()

# %%
sns.barplot(data=df, x="성별코드", y="시력(좌)")

# %%
df_eye = df_sample[(df_sample["시력(좌)"] < 3) & (df_sample["시력(우)"] < 3)]

# %%
sns.distplot(df_eye["시력(좌)"], bins=10)
sns.distplot(df_eye["시력(우)"], bins=10)

# %%
sns.lmplot(
    data=df_eye, x="시력(좌)", 
    y="시력(우)", hue="연령대코드(5세단위)", col="연령대코드(5세단위)", col_wrap=3)

# %%
df["흡연상태"].value_counts()
# Out:
# 1.0    608587
# 3.0    215061
# 2.0    176192
# Name: 흡연상태, dtype: int64

# %%
df["음주여부"].value_counts()
# Out:
# 0.0    502729
# 1.0    496746
# Name: 음주여부, dtype: int64

# %%
sns.scatterplot(data=df_sample, x="수축기혈압", y="이완기혈압", hue="연령대코드(5세단위)")

# %%
df_man = df_sample[df_sample["성별코드"] == 1].sample(1000)
df_small = df_man[['연령대코드(5세단위)', '체중(5Kg 단위)', '허리둘레', '시력(좌)', '시력(우)', '청력(좌)', '청력(우)', '수축기혈압',
       '이완기혈압', '식전혈당(공복혈당)', '총콜레스테롤', '트리글리세라이드', 'HDL콜레스테롤', 'LDL콜레스테롤',
       '혈색소', '요단백', '혈청크레아티닌', '(혈청지오티)AST', '(혈청지오티)ALT', '감마지티피', '흡연상태',
       '음주여부']]
df_corr = df_small.corr()
df_corr
# Out:
#              연령대코드(5세단위)  체중(5Kg 단위)      허리둘레     시력(좌)     시력(우)     청력(좌)  \
# 연령대코드(5세단위)     1.000000   -0.349749 -0.007208 -0.170740 -0.292905  0.223896
# 체중(5Kg 단위)     -0.349749    1.000000  0.797780  0.074888  0.096626 -0.066274
# 허리둘레           -0.007208    0.797780  1.000000 -0.005698 -0.019475  0.016892
# 시력(좌)          -0.170740    0.074888 -0.005698  1.000000  0.338170 -0.080309
# 시력(우)          -0.292905    0.096626 -0.019475  0.338170  1.000000 -0.108698
# 청력(좌)           0.223896   -0.066274  0.016892 -0.080309 -0.108698  1.000000
# 청력(우)           0.200128   -0.041777  0.034246 -0.086123 -0.096015  0.498240
# 수축기혈압           0.165152    0.153007  0.211766  0.001910 -0.037382  0.061248
# 이완기혈압           0.012317    0.173217  0.192584 -0.028763 -0.010032 -0.020402
# 식전혈당(공복혈당)      0.125726    0.086700  0.191055 -0.014799 -0.044011 -0.000421
# 총콜레스테롤         -0.104625    0.050939  0.023522  0.039014  0.051708 -0.081726
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df_corr, vmax=.8, square=False, annot=True)
